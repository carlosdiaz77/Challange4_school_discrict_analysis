# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read the School Data and Student Data and store into a Pandas DataFrame
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Cleaning Student Names and Replacing Substrings in a Python String
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# Check names.
student_data_df.sample(10)
# Out:
# C:\Users\votre\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#        Student ID       student_name gender grade            school_name  \
# 5302         5302     Robert Walters      M  12th   Figueroa High School
# 21198       21198  Kristopher Murphy      M   9th     Bailey High School
# 687           687   Jessica Thompson      F  10th      Huang High School
# 2859         2859     Michael Fisher      M  10th      Huang High School
# 16639       16639    Briana Williams      F  12th    Cabrera High School
# 10070       10070     Craig Mitchell      M  10th  Hernandez High School
# 25846       25846        Angela Hart      F  11th     Wright High School
# 18034       18034   Russell Gonzalez      M  11th     Bailey High School
# 32271       32271   Lawrence Serrano      M  10th    Johnson High School
# ...

# %% [markdown]
# ## Deliverable 1: Replace the reading and math scores.
#
# ### Replace the 9th grade reading and math scores at Thomas High School with NaN.

# %%
# Install numpy using conda install numpy or pip install numpy. 
# Step 1. Import numpy as np.
import numpy as np

# %%
# Step 2. Use the loc method on the student_data_df to select all the reading scores from the 9th grade at Thomas High School and replace them with NaN.
#student_data_df.loc[]
student_data_df.loc[(student_data_df["school_name"]=="Thomas High School") 
                 & (student_data_df["grade"]=="9th") ,"reading_score" ]=np.nan

# %%
#  Step 3. Refactor the code in Step 2 to replace the math scores with NaN.
student_data_df.loc[(student_data_df["school_name"]=="Thomas High School") 
                 & (student_data_df["grade"]=="9th") ,"math_score" ]=np.nan

# %%
#  Step 4. Check the student data for NaN's. 
THS_9th_df=student_data_df.loc[(student_data_df["school_name"]=="Thomas High School") 
                 & (student_data_df["grade"]=="9th")]
THS_9th_df
# Out:
#        Student ID      student_name gender grade         school_name  \
# 37537       37537       Erik Snyder      M   9th  Thomas High School
# 37538       37538    Tanya Martinez      F   9th  Thomas High School
# 37539       37539     Noah Erickson      M   9th  Thomas High School
# 37540       37540      Austin Meyer      M   9th  Thomas High School
# 37543       37543   Madison Hampton      F   9th  Thomas High School
# ...           ...               ...    ...   ...                 ...
# 39152       39152        Lori Moore      F   9th  Thomas High School
# 39153       39153   William Hubbard      M   9th  Thomas High School
# 39157       39157  Kristen Gonzalez      F   9th  Thomas High School
# 39164       39164    Joseph Anthony      M   9th  Thomas High School
# 39167       39167    Rebecca Tanner      F   9th  Thomas High School
#
#        reading_score  math_score
# 37537            NaN         NaN
# 37538            NaN         NaN
# 37539            NaN         NaN
# ...

# %% [markdown]
# ## Deliverable 2 : Repeat the school district analysis

# %% [markdown]
# ### District Summary

# %%
# Combine the data into a single dataset
school_data_complete_df = pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])
school_data_complete_df.head()
#school_data_complete_df.to_csv('initial_files.csv') # it exports the DataFrame to excel CSV
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School           66.0
# 1           1     Victor Smith      M  12th  Huang High School           94.0
# 2           2  Kevin Rodriguez      M  12th  Huang High School           90.0
# 3           3    Richard Scott      M  12th  Huang High School           67.0
# 4           4       Bonnie Ray      F   9th  Huang High School           97.0
#
#    math_score  School ID      type  size   budget
# 0        79.0          0  District  2917  1910635
# 1        61.0          0  District  2917  1910635
# 2        60.0          0  District  2917  1910635
# 3        58.0          0  District  2917  1910635
# 4        84.0          0  District  2917  1910635

# %%
# Calculate the Totals (Schools and Students)
school_count = len(school_data_complete_df["school_name"].unique())
student_count = school_data_complete_df["Student ID"].count()

# Calculate the Total Budget
total_budget = school_data_df["budget"].sum()

# %%
# Calculate the Average Scores using the "clean_student_data".
average_reading_score = school_data_complete_df["reading_score"].mean()
average_math_score = school_data_complete_df["math_score"].mean()

# %%
# Step 1. Get the number of students that are in ninth grade at Thomas High School.
# These students have no grades. 
student_count_Thomas_9th=THS_9th_df['Student ID'].count()

print(f' Total students in 9th grade at Thomas High School is:{student_count_Thomas_9th}')

# Get the total student count 
student_count = school_data_complete_df["Student ID"].count()
print(f' Total students in all High Schools is:{student_count}')

# Step 2. Subtract the number of students that are in ninth grade at 
# Thomas High School from the total student count to get the new total student count.
New_student_count= student_count - student_count_Thomas_9th
print(f' The new Student count is:{New_student_count}')
# Out:
#  Total students in 9th grade at Thomas High School is:461
#  Total students in all High Schools is:39170
#  The new Student count is:38709

# %%
# Calculate the passing rates using the "clean_student_data".
passing_math_count = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)].count()["student_name"]
passing_reading_count = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)].count()["student_name"]

# %%
# Step 3. Calculate the passing percentages with the new total student count.
passing_math_percentage= passing_math_count/New_student_count
print(f' The Math Passing average is : {passing_math_percentage}')
passing_reading_percentage= passing_reading_count/New_student_count
print(f' The Reading Passing average is : {passing_reading_percentage}')
# Out:
#  The Math Passing average is : 0.7476039164018704
#  The Reading Passing average is : 0.856596657108166

# %%
# Calculate the students who passed both reading and math.
passing_math_reading = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)
                                               & (school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students that passed both reading and math.
overall_passing_math_reading_count = passing_math_reading["student_name"].count()


# Step 4.Calculate the overall passing percentage with new total student count.

overall_passing_percentage=overall_passing_math_reading_count/New_student_count
print(f' The Overall Reading and Math Passing average is : {overall_passing_percentage}')
# Out:
#  The Overall Reading and Math Passing average is : 0.6485571830840373

# %%
# Create a DataFrame
district_summary_df = pd.DataFrame(
          [{"Total Schools": school_count, 
          "Total Students": student_count, 
          "Total Budget": total_budget,
          "Average Math Score": average_math_score, 
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": overall_passing_percentage}])



# Format the "Total Students" to have the comma for a thousands separator.
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
# Format the "Total Budget" to have the comma for a thousands separator, a decimal separator and a "$".
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.0f}".format)
# Format the columns.
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.1%}".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.1%}".format)
district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.1%}".format)




# Display the data frame
# Align  the values in a DataFrame (right, center, left)
district_summary_df.style.set_properties(**{'text-align': 'center'})
#district_summary_df
# Out:
# <style  type="text/css" >
# #T_934c2_row0_col0,#T_934c2_row0_col1,#T_934c2_row0_col2,#T_934c2_row0_col3,#T_934c2_row0_col4,#T_934c2_row0_col5,#T_934c2_row0_col6,#T_934c2_row0_col7{
#             text-align:  center;
#         }</style><table id="T_934c2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_934c2_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ##  School Summary

# %%
# Determine the School Type
per_school_types = school_data_df.set_index(["school_name"])["type"]

# Calculate the total student count.
per_school_counts = school_data_complete_df["school_name"].value_counts()

# Calculate the total school budget and per capita spending
per_school_budget = school_data_complete_df.groupby(["school_name"]).mean()["budget"]
# Calculate the per capita spending.
per_school_capita = per_school_budget / per_school_counts

# Calculate the average test scores.
per_school_math = school_data_complete_df.groupby(["school_name"]).mean()["math_score"]
per_school_reading = school_data_complete_df.groupby(["school_name"]).mean()["reading_score"]

# Calculate the passing scores by creating a filtered DataFrame.
per_school_passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
per_school_passing_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_school_passing_math = per_school_passing_math.groupby(["school_name"]).count()["student_name"]
per_school_passing_reading = per_school_passing_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_school_passing_math = per_school_passing_math / per_school_counts * 100
per_school_passing_reading = per_school_passing_reading / per_school_counts * 100

# Calculate the students who passed both reading and math.
per_passing_math_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)
                                               & (school_data_complete_df["math_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_passing_math_reading = per_passing_math_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_overall_passing_percentage = per_passing_math_reading / per_school_counts * 100

# %%
# Create the DataFrame
per_school_summary_df = pd.DataFrame({
    "School Type": per_school_types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": per_school_math,
    "Average Reading Score": per_school_reading,
    "% Passing Math": per_school_passing_math,
    "% Passing Reading": per_school_passing_reading,
    "% Overall Passing": per_overall_passing_percentage})


# per_school_summary_df.head()

# %%
# Format the Total School Budget and the Per Student Budget
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.0f}".format)
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.0f}".format)

# Display the data frame
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976          $3,124,928
# Cabrera High School       Charter            1858          $1,081,356
# Figueroa High School     District            2949          $1,884,411
# Ford High School         District            2739          $1,763,916
# Griffin High School       Charter            1468            $917,500
# Hernandez High School    District            4635          $3,022,020
# Holden High School        Charter             427            $248,087
# Huang High School        District            2917          $1,910,635
# Johnson High School      District            4761          $3,094,650
# Pena High School          Charter             962            $585,858
# Rodriguez High School    District            3999          $2,547,363
# Shelton High School       Charter            1761          $1,056,600
# ...

# %%
# Step 5.  Get the number of 10th-12th graders from Thomas High School (THS).

variant_filter=(school_data_complete_df["school_name"]=="Thomas High School") & (school_data_complete_df["grade"]!="9th")
THS_10to12_ss_df=school_data_complete_df.loc[variant_filter,:]
THS_10to12_ss_df
THS_10to12_ss_count=THS_10to12_ss_df['student_name'].count()
THS_10to12_ss_count
# Out:
# 1174

# %%
THS_10to12_ss_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 37535       37535         Norma Mata      F  10th  Thomas High School
# 37536       37536        Cody Miller      M  11th  Thomas High School
# 37541       37541       Eric Stevens      M  10th  Thomas High School
# 37542       37542  Elizabeth Bennett      F  11th  Thomas High School
# 37544       37544  Jacqueline Harris      F  10th  Thomas High School
# ...           ...                ...    ...   ...                 ...
# 39163       39163         John Reese      M  11th  Thomas High School
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# ...

# %%
# Step 6. Get all the students passing math from THS
THS_10to12_passing_math_count = THS_10to12_ss_df[(THS_10to12_ss_df["math_score"] >= 70)].count()["student_name"]
print(f' {THS_10to12_passing_math_count} students passed MATH with a score over 70 at Thomas High School')
# Out:
#  1094 students passed MATH with a score over 70 at Thomas High School

# %%
# Step 7. Get all the students passing reading from THS
THS_10to12_passing_reading_count = THS_10to12_ss_df[(THS_10to12_ss_df["reading_score"] >= 70)].count()['student_name']
print(f' {THS_10to12_passing_reading_count} students passed READING with a score over 70 at Thomas High School' )
# Out:
#  1139 students passed READING with a score over 70 at Thomas High School

# %%
# Step 8. Get all the students passing math and reading from THS

THS_passing_math_reading = THS_10to12_ss_df[(THS_10to12_ss_df["math_score"] >= 70)
                                               & (THS_10to12_ss_df["reading_score"] >= 70)]
THS_passing_math_reading=THS_passing_math_reading['student_name'].count()
print(f' {THS_passing_math_reading} stundents in Thomas High School passed BOTH Math and Reading with a score over 70')
# Out:
#  1064 stundents in Thomas High School passed BOTH Math and Reading with a score over 70

# %%
# Step 9. Calculate the percentage of 10th-12th grade students passing math from Thomas High School. 
THS_10to12_passing_math_percetage= THS_10to12_passing_math_count/THS_10to12_ss_count*100
THS_10to12_passing_math_percetage
print(f'Thomas High School Passing  MATH percentage is: {THS_10to12_passing_math_percetage}')
# Out:
# Thomas High School Passing  MATH percentage is: 93.18568994889267

# %%
# Step 10. Calculate the percentage of 10th-12th grade students passing reading from Thomas High School.
THS_10to12_passing_reading_percetage= THS_10to12_passing_reading_count/THS_10to12_ss_count*100
THS_10to12_passing_reading_percetage
print(f'Thomas High School passing  READING percentage is: {THS_10to12_passing_reading_percetage}')
# Out:
# Thomas High School passing  READING percentage is: 97.01873935264055

# %%
# Step 11. Calculate the overall passing percentage of 10th-12th grade from Thomas High School. 
THS_10to12_passing_math_reading_percetage= THS_passing_math_reading/THS_10to12_ss_count*100
THS_10to12_passing_math_reading_percetage
print(f'Thomas High School OVERALL passing percentage is: {THS_10to12_passing_math_reading_percetage}')
# Out:
# Thomas High School OVERALL passing percentage is: 90.63032367972743

# %%
THS_per_school_math = THS_10to12_ss_df["math_score"].mean()
THS_per_school_read = THS_10to12_ss_df["reading_score"].mean()
print(f' Thomas High school average scores  for Math {THS_per_school_math} & for Reading {THS_per_school_read}')
# Out:
#  Thomas High school average scores  for Math 83.35093696763202 & for Reading 83.89608177172062

# %%
# Step 12. Replace the passing math percent for Thomas High School in the per_school_summary_df.
per_school_summary_df.at["Thomas High School","% Passing Math"]=93.18569

# %%
# Step 13. Replace the passing reading percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.at["Thomas High School","% Passing Reading"]=97.018739

# %%
# Step 14. Replace the overall passing percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.at["Thomas High School","% Overall Passing"]=90.630324

# %%
# per_school_summary_df
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976          $3,124,928
# Cabrera High School       Charter            1858          $1,081,356
# Figueroa High School     District            2949          $1,884,411
# Ford High School         District            2739          $1,763,916
# Griffin High School       Charter            1468            $917,500
# Hernandez High School    District            4635          $3,022,020
# Holden High School        Charter             427            $248,087
# Huang High School        District            2917          $1,910,635
# Johnson High School      District            4761          $3,094,650
# Pena High School          Charter             962            $585,858
# Rodriguez High School    District            3999          $2,547,363
# Shelton High School       Charter            1761          $1,056,600
# ...

# %% [markdown]
# ## High and Low Performing Schools

# %%
# Sort and show top five schools.
per_school_summary_df = per_school_summary_df.sort_values(["% Overall Passing"], ascending=False) # Hightest on top.
per_school_summary_df.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858          $1,081,356
# Thomas High School      Charter            1635          $1,043,130
# Griffin High School     Charter            1468            $917,500
# Wilson High School      Charter            2283          $1,319,574
# Pena High School        Charter             962            $585,858
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School               $582           83.061895
# Thomas High School                $638           83.350937
# Griffin High School               $625           83.351499
# Wilson High School                $578           83.274201
# Pena High School                  $609           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
# Sort and show bottom five schools.
per_school_summary_df = per_school_summary_df.sort_values(["% Overall Passing"], ascending=True) # Hightest on top.
per_school_summary_df.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999          $2,547,363
# Figueroa High School     District            2949          $1,884,411
# Huang High School        District            2917          $1,910,635
# Hernandez High School    District            4635          $3,022,020
# Johnson High School      District            4761          $3,094,650
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School               $637           76.842711
# Figueroa High School                $639           76.711767
# Huang High School                   $655           76.629414
# Hernandez High School               $652           77.289752
# Johnson High School                 $650           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# ## Math and Reading Scores by Grade

# %%
#The average math score for each grade level from each school (3 pt)

Grouped_School_grade_Math= school_data_complete_df.groupby(["school_name","grade"]).mean()["math_score"]
Grouped_School_grade_Math
# Out:
# school_name            grade
# Bailey High School     10th     76.996772
#                        11th     77.515588
#                        12th     76.492218
#                        9th      77.083676
# Cabrera High School    10th     83.154506
#                        11th     82.765560
#                        12th     83.277487
#                        9th      83.094697
# Figueroa High School   10th     76.539974
#                        11th     76.884344
#                        12th     77.151369
#                        9th      76.403037
# Ford High School       10th     77.672316
#                        11th     76.918058
#                        12th     76.179963
#                        9th      77.361345
# Griffin High School    10th     84.229064
#                        11th     83.842105
#                        12th     83.356164
#                        9th      82.044010
# Hernandez High School  10th     77.337408
#                        11th     77.136029
# ...

# %%
#The average reading score for each grade level from each school (3 pt)
Grouped_School_grade_Reading=school_data_complete_df.groupby(["school_name","grade"]).mean()["reading_score"]
Grouped_School_grade_Reading
# Out:
# school_name            grade
# Bailey High School     10th     80.907183
#                        11th     80.945643
#                        12th     80.912451
#                        9th      81.303155
# Cabrera High School    10th     84.253219
#                        11th     83.788382
#                        12th     84.287958
#                        9th      83.676136
# Figueroa High School   10th     81.408912
#                        11th     80.640339
#                        12th     81.384863
#                        9th      81.198598
# Ford High School       10th     81.262712
#                        11th     80.403642
#                        12th     80.662338
#                        9th      80.632653
# Griffin High School    10th     83.706897
#                        11th     84.288089
#                        12th     84.013699
#                        9th      83.369193
# Hernandez High School  10th     80.660147
#                        11th     81.396140
# ...

# %%
 #Create a grade level DataFrames.
ninth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "9th")]

tenth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "10th")]

eleventh_graders = school_data_complete_df[(school_data_complete_df["grade"] == "11th")]

twelfth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "12th")]

# %%
# Group each grade level DataFrame by the school name for the average math score.
ninth_grade_math_scores = ninth_graders.groupby(["school_name"]).mean()["math_score"]/100

tenth_grade_math_scores = tenth_graders.groupby(["school_name"]).mean()["math_score"]/100

eleventh_grade_math_scores = eleventh_graders.groupby(["school_name"]).mean()["math_score"]/100

twelfth_grade_math_scores = twelfth_graders.groupby(["school_name"]).mean()["math_score"]/100

# %%
# Group each grade level DataFrame by the school name for the average reading score.
ninth_grade_reading_scores = ninth_graders.groupby(["school_name"]).mean()["reading_score"]/100

tenth_grade_reading_scores = tenth_graders.groupby(["school_name"]).mean()["reading_score"]/100

eleventh_grade_reading_scores = eleventh_graders.groupby(["school_name"]).mean()["reading_score"]/100

twelfth_grade_reading_scores = twelfth_graders.groupby(["school_name"]).mean()["reading_score"]/100

# %%
# Combine each grade level Series for average math scores by school into a single DataFrame.
math_scores_by_grade = pd.DataFrame({
               "9th": ninth_grade_math_scores,
               "10th": tenth_grade_math_scores,
               "11th": eleventh_grade_math_scores,
               "12th": twelfth_grade_math_scores})

math_scores_by_gr